# %%
import pandas as pd

df_book = pd.read_csv("/content/drive/MyDrive/KPDL/BTL/books.csv")

df_book = df_book.drop('Unnamed: 0', axis = 1)

df_book = df_book[['product_id','current_price', 'quantity', 'category', 'n_review', 'avg_rating', 'manufacturer']]
df_book
# Out:
#       product_id  current_price  quantity                  category  n_review  \
# 0       74021317          64800     53075               Tiểu Thuyết     11481
# 1      184466860          59900      7929                    Others       780
# 2       73787185         126000     17896             Lĩnh vực khác      3623
# 3       52789367          47400     24668        Tác phẩm kinh điển      5131
# 4      147920903          81000     10000               Tiểu Thuyết      1636
# ...          ...            ...       ...                       ...       ...
# 1763   192949122         191200        76                    Others         7
# 1764   157579054          48900       147                    Others        20
# 1765    20704715          43200       931           Sách Làm Cha Mẹ        47
# 1766   131144753         107500       378   Sách quản trị, lãnh đạo        33
# 1767    58971672          91000       954  Sách nghệ thuật sống đẹp       176
#
#       avg_rating                  manufacturer
# 0            5.0      Nhà Xuất Bản Hội Nhà Văn
# 1            4.8         Nhà Xuất Bản Thế Giới
# 2            4.8      Nhà Xuất Bản Hội Nhà Văn
# 3            5.0           Nhà Xuất Bản Hà Nội
# 4            4.8      Nhà Xuất Bản Hội Nhà Văn
# ...          ...                           ...
# 1763         5.0  Nhà Xuất Bản Tổng hợp TP.HCM
# 1764         5.0  Nhà Xuất Bản Khoa Học Xã Hội
# 1765         4.6                       Unknown
# 1766         5.0         Nhà Xuất Bản Lao Động
# 1767         5.0  Nhà Xuất Bản Tổng hợp TP.HCM
#
# [1768 rows x 7 columns]

# %%
a = df_book.sort_values(by=['quantity'], ascending=False)
a
# Out:
#       product_id  current_price  quantity                  category  n_review  \
# 121     75307228         110800    671121  Sách nghệ thuật sống đẹp      1855
# 36      26114399          57001     65623                    Others      6602
# 491       750578          68670     59734          Tiểu sử - Hồi ký      2099
# 0       74021317          64800     53075               Tiểu Thuyết     11481
# 44      10005245         135300     48419                    Others      3904
# ...          ...            ...       ...                       ...       ...
# 1376    35283865          61200         1         Văn học thiếu nhi         0
# 1347    73687713         121500         1             Lĩnh vực khác         1
# 1658   138143167         205200         1                    Others         0
# 1068    27962195          44000         1         Truyện tranh Ehon         0
# 528    200672813         308000         1  Sách nghệ thuật sống đẹp         0
#
#       avg_rating                            manufacturer
# 121          5.0  Nhà Xuất Bản Văn Hóa - Văn Nghệ TP.HCM
# 36           4.8                                 Unknown
# 491          4.7                                 Unknown
# 0            5.0                Nhà Xuất Bản Hội Nhà Văn
# 44           4.7                                 Unknown
# ...          ...                                     ...
# 1376         0.0                                 Unknown
# 1347         5.0                    Nhà Xuất Bản Dân Trí
# 1658         0.0                    Nhà Xuất Bản Dân Trí
# 1068         0.0                   Nhà Xuất Bản Thế Giới
# 528          0.0                   Nhà Xuất Bản Thế Giới
#
# [1768 rows x 7 columns]

# %%
df_book = df_book.drop(121)

# %%
df_book['quantity'].max()
# Out:
# 65623

# %%
min_quan = df_book['quantity'].min()
max_quan = df_book['quantity'].max()
df_book['quantity_new'] = ((df_book[['quantity']] -min_quan)) /(max_quan -min_quan).round(3)
df_book
# Out:
#       product_id  current_price  quantity                  category  n_review  \
# 0       74021317          64800     53075               Tiểu Thuyết     11481
# 1      184466860          59900      7929                    Others       780
# 2       73787185         126000     17896             Lĩnh vực khác      3623
# 3       52789367          47400     24668        Tác phẩm kinh điển      5131
# 4      147920903          81000     10000               Tiểu Thuyết      1636
# ...          ...            ...       ...                       ...       ...
# 1763   192949122         191200        76                    Others         7
# 1764   157579054          48900       147                    Others        20
# 1765    20704715          43200       931           Sách Làm Cha Mẹ        47
# 1766   131144753         107500       378   Sách quản trị, lãnh đạo        33
# 1767    58971672          91000       954  Sách nghệ thuật sống đẹp       176
#
#       avg_rating                  manufacturer  quantity_new
# 0            5.0      Nhà Xuất Bản Hội Nhà Văn      0.808784
# 1            4.8         Nhà Xuất Bản Thế Giới      0.120813
# 2            4.8      Nhà Xuất Bản Hội Nhà Văn      0.272698
# 3            5.0           Nhà Xuất Bản Hà Nội      0.375895
# 4            4.8      Nhà Xuất Bản Hội Nhà Văn      0.152373
# ...          ...                           ...           ...
# 1763         5.0  Nhà Xuất Bản Tổng hợp TP.HCM      0.001143
# 1764         5.0  Nhà Xuất Bản Khoa Học Xã Hội      0.002225
# 1765         4.6                       Unknown      0.014172
# 1766         5.0         Nhà Xuất Bản Lao Động      0.005745
# 1767         5.0  Nhà Xuất Bản Tổng hợp TP.HCM      0.014523
#
# [1767 rows x 8 columns]

# %%
min_price = df_book['current_price'].min()
max_price = df_book['current_price'].max()
df_book['current_price_new'] = ((df_book[['current_price']] -min_price)) /(max_price -min_price).round(3)
df_book
# Out:
#       product_id  current_price  quantity                  category  n_review  \
# 0       74021317          64800     53075               Tiểu Thuyết     11481
# 1      184466860          59900      7929                    Others       780
# 2       73787185         126000     17896             Lĩnh vực khác      3623
# 3       52789367          47400     24668        Tác phẩm kinh điển      5131
# 4      147920903          81000     10000               Tiểu Thuyết      1636
# ...          ...            ...       ...                       ...       ...
# 1763   192949122         191200        76                    Others         7
# 1764   157579054          48900       147                    Others        20
# 1765    20704715          43200       931           Sách Làm Cha Mẹ        47
# 1766   131144753         107500       378   Sách quản trị, lãnh đạo        33
# 1767    58971672          91000       954  Sách nghệ thuật sống đẹp       176
#
#       avg_rating                  manufacturer  quantity_new  \
# 0            5.0      Nhà Xuất Bản Hội Nhà Văn      0.808784
# 1            4.8         Nhà Xuất Bản Thế Giới      0.120813
# 2            4.8      Nhà Xuất Bản Hội Nhà Văn      0.272698
# 3            5.0           Nhà Xuất Bản Hà Nội      0.375895
# 4            4.8      Nhà Xuất Bản Hội Nhà Văn      0.152373
# ...          ...                           ...           ...
# 1763         5.0  Nhà Xuất Bản Tổng hợp TP.HCM      0.001143
# 1764         5.0  Nhà Xuất Bản Khoa Học Xã Hội      0.002225
# 1765         4.6                       Unknown      0.014172
# 1766         5.0         Nhà Xuất Bản Lao Động      0.005745
# 1767         5.0  Nhà Xuất Bản Tổng hợp TP.HCM      0.014523
#
#       current_price_new
# 0              0.054000
# 1              0.049917
# 2              0.105000
# 3              0.039500
# 4              0.067500
# ...                 ...
# 1763           0.159333
# 1764           0.040750
# 1765           0.036000
# 1766           0.089583
# 1767           0.075833
#
# [1767 rows x 9 columns]

# %%
min_review = df_book['n_review'].min()
max_review = df_book['n_review'].max()
df_book['n_review_new'] = ((df_book[['n_review']] -min_review)) /(max_review -min_review).round(3)
df_book
# Out:
#       product_id  current_price  quantity                  category  n_review  \
# 0       74021317          64800     53075               Tiểu Thuyết     11481
# 1      184466860          59900      7929                    Others       780
# 2       73787185         126000     17896             Lĩnh vực khác      3623
# 3       52789367          47400     24668        Tác phẩm kinh điển      5131
# 4      147920903          81000     10000               Tiểu Thuyết      1636
# ...          ...            ...       ...                       ...       ...
# 1763   192949122         191200        76                    Others         7
# 1764   157579054          48900       147                    Others        20
# 1765    20704715          43200       931           Sách Làm Cha Mẹ        47
# 1766   131144753         107500       378   Sách quản trị, lãnh đạo        33
# 1767    58971672          91000       954  Sách nghệ thuật sống đẹp       176
#
#       avg_rating                  manufacturer  quantity_new  \
# 0            5.0      Nhà Xuất Bản Hội Nhà Văn      0.808784
# 1            4.8         Nhà Xuất Bản Thế Giới      0.120813
# 2            4.8      Nhà Xuất Bản Hội Nhà Văn      0.272698
# 3            5.0           Nhà Xuất Bản Hà Nội      0.375895
# 4            4.8      Nhà Xuất Bản Hội Nhà Văn      0.152373
# ...          ...                           ...           ...
# 1763         5.0  Nhà Xuất Bản Tổng hợp TP.HCM      0.001143
# 1764         5.0  Nhà Xuất Bản Khoa Học Xã Hội      0.002225
# 1765         4.6                       Unknown      0.014172
# 1766         5.0         Nhà Xuất Bản Lao Động      0.005745
# 1767         5.0  Nhà Xuất Bản Tổng hợp TP.HCM      0.014523
#
#       current_price_new  n_review_new
# 0              0.054000      1.000000
# 1              0.049917      0.067938
# 2              0.105000      0.315565
# 3              0.039500      0.446912
# 4              0.067500      0.142496
# ...                 ...           ...
# 1763           0.159333      0.000610
# 1764           0.040750      0.001742
# 1765           0.036000      0.004094
# 1766           0.089583      0.002874
# 1767           0.075833      0.015330
#
# [1767 rows x 10 columns]

# %%
min_rating = df_book['avg_rating'].min()
max_rating = df_book['avg_rating'].max()
df_book['avg_rating_new'] = ((df_book[['avg_rating']] -min_rating)) /(max_rating -min_rating).round(3)
df_book
# Out:
#       product_id  current_price  quantity                  category  n_review  \
# 0       74021317          64800     53075               Tiểu Thuyết     11481
# 1      184466860          59900      7929                    Others       780
# 2       73787185         126000     17896             Lĩnh vực khác      3623
# 3       52789367          47400     24668        Tác phẩm kinh điển      5131
# 4      147920903          81000     10000               Tiểu Thuyết      1636
# ...          ...            ...       ...                       ...       ...
# 1763   192949122         191200        76                    Others         7
# 1764   157579054          48900       147                    Others        20
# 1765    20704715          43200       931           Sách Làm Cha Mẹ        47
# 1766   131144753         107500       378   Sách quản trị, lãnh đạo        33
# 1767    58971672          91000       954  Sách nghệ thuật sống đẹp       176
#
#       avg_rating                  manufacturer  quantity_new  \
# 0            5.0      Nhà Xuất Bản Hội Nhà Văn      0.808784
# 1            4.8         Nhà Xuất Bản Thế Giới      0.120813
# 2            4.8      Nhà Xuất Bản Hội Nhà Văn      0.272698
# 3            5.0           Nhà Xuất Bản Hà Nội      0.375895
# 4            4.8      Nhà Xuất Bản Hội Nhà Văn      0.152373
# ...          ...                           ...           ...
# 1763         5.0  Nhà Xuất Bản Tổng hợp TP.HCM      0.001143
# 1764         5.0  Nhà Xuất Bản Khoa Học Xã Hội      0.002225
# 1765         4.6                       Unknown      0.014172
# 1766         5.0         Nhà Xuất Bản Lao Động      0.005745
# 1767         5.0  Nhà Xuất Bản Tổng hợp TP.HCM      0.014523
#
#       current_price_new  n_review_new  avg_rating_new
# 0              0.054000      1.000000            1.00
# 1              0.049917      0.067938            0.96
# 2              0.105000      0.315565            0.96
# 3              0.039500      0.446912            1.00
# 4              0.067500      0.142496            0.96
# ...                 ...           ...             ...
# 1763           0.159333      0.000610            1.00
# 1764           0.040750      0.001742            1.00
# 1765           0.036000      0.004094            0.92
# 1766           0.089583      0.002874            1.00
# 1767           0.075833      0.015330            1.00
#
# [1767 rows x 11 columns]

# %%
# Thống kê tần suất xuất hiện
frequency_table = df_book['manufacturer'].value_counts().sort_index().reset_index()
frequency_table.columns = ['manufacturer', 'Tần suất xuất hiện']

# Tính giá trị nhỏ nhất
min_frequency = frequency_table['Tần suất xuất hiện'].min()
# Tính giá trị lớn nhất
max_frequency = frequency_table['Tần suất xuất hiện'].max()

frequency_table['Tần suất xuất hiện'] = frequency_table['Tần suất xuất hiện'].apply(lambda x: (x-min_frequency)/(max_frequency-min_frequency)).round(4)
frequency_table
# Out:
#                                      manufacturer  Tần suất xuất hiện
# 0                                 Forbes Việt Nam              0.0038
# 1                                         NXB Trẻ              0.5379
# 2                    NXB Đại học Kinh Tế Quốc Dân              0.0076
# 3                              Nhiều Nhà Xuất Bản              0.0189
# 4         Nhà Xuất Bản Chính Trị Quốc Gia Sự Thật              0.0114
# 5                 Nhà Xuất Bản Compass Publishing              0.0000
# 6                        Nhà Xuất Bản Công Thương              0.1705
# 7                            Nhà Xuất Bản Dân Trí              0.4962
# 8                  Nhà Xuất Bản Giáo Dục Việt Nam              0.0000
# 9                             Nhà Xuất Bản Hà Nội              0.4811
# 10                          Nhà Xuất Bản Hồng Đức              0.2197
# 11  Nhà Xuất Bản Hồng Đức - Hội Luật Gia Việt Nam              0.0000
# 12                       Nhà Xuất Bản Hội Nhà Văn              0.4167
# 13                   Nhà Xuất Bản Khoa Học Xã Hội              0.0152
# 14               Nhà Xuất Bản Khoa học & kỹ thuật              0.0038
# 15                          Nhà Xuất Bản Kim Đồng              0.4242
# 16                     Nhà Xuất Bản Kinh Tế TPHCM              0.0076
# 17                          Nhà Xuất Bản Lao Động              0.3333
# 18                   Nhà Xuất Bản Lao Động Xã Hội              0.0227
# 19                          Nhà Xuất Bản Mỹ Thuật              0.0265
# 20                            Nhà Xuất Bản Phụ Nữ              0.1098
# 21                   Nhà Xuất Bản Phụ Nữ Việt Nam              0.1402
# 22                        Nhà Xuất Bản Thanh Niên              0.3636
# 23         Nhà Xuất Bản Thông Tin Và Truyền Thông              0.0076
# 24                         Nhà Xuất Bản Thông Tấn              0.0038
# 25                          Nhà Xuất Bản Thế Giới              0.9318
# 26                          Nhà Xuất Bản Thời Đại              0.0000
# 27                          Nhà Xuất Bản Tri Thức              0.0227
# 28                         Nhà Xuất Bản Tài Chính              0.0152
# 29                          Nhà Xuất Bản Tôn Giáo              0.0038
# 30                   Nhà Xuất Bản Tổng hợp TP.HCM              0.3409
# 31                   Nhà Xuất Bản Văn Hoá Dân Tộc              0.0000
# 32         Nhà Xuất Bản Văn Hóa - Văn Nghệ TP.HCM              0.0038
# 33                           Nhà Xuất Bản Văn Học              0.2879
# 34                           Nhà Xuất Bản Đà Nẵng              0.0568
# 35          Nhà Xuất Bản Đại Học Kinh Tế Quốc Dân              0.0038
# 36           Nhà Xuất Bản Đại Học Quốc Gia Hà Nội              0.0492
# 37                          Nhà Xuất Bản Đồng Nai              0.0076
# 38                                        Unknown              1.0000

# %%
data_new = df_book.merge(frequency_table[['manufacturer', 'Tần suất xuất hiện']], on='manufacturer')
data_new = data_new.rename(columns={'Tần suất xuất hiện':'manufacturer_new'})
data_new['manufacturer_new'] = 1 - data_new['manufacturer_new']

# %%
# Thống kê tần suất xuất hiện
frequency_table_cate = df_book['category'].value_counts().sort_index().reset_index()

frequency_table_cate.columns = ['category', 'cate_freq']

frequency_table_cate

# Tính giá trị nhỏ nhất
min_frequency_cate = frequency_table_cate['cate_freq'].min()
# Tính giá trị lớn nhất
max_frequency_cate = frequency_table_cate['cate_freq'].max()

frequency_table_cate['cate_freq'] = frequency_table_cate['cate_freq'].apply(lambda x: (x-min_frequency_cate)/(max_frequency_cate-min_frequency_cate)).round(4)

# %%
frequency_table_cate
# Out:
#                                    category  cate_freq
# 0                        Bài học kinh doanh     0.0544
# 1                       Kiến Thức Bách Khoa     0.0146
# 2                     Kiến thức - Bách khoa     0.0279
# 3                               Light novel     0.0093
# 4                             Lĩnh vực khác     0.0252
# 5                          Lịch Sử Thế Giới     0.0027
# 6                                    Others     1.0000
# 7               Sách Chiêm Tinh - Horoscope     0.0027
# 8                        Sách Học Tiếng Anh     0.0385
# 9                        Sách Học Tiếng Hoa     0.0027
# 10                          Sách Làm Cha Mẹ     0.0265
# 11               Sách Marketing - Bán hàng      0.0371
# 12                            Sách giáo dục     0.0013
# 13                         Sách kinh tế học     0.0013
# 14                    Sách kỹ năng làm việc     0.0570
# 15                 Sách nghệ thuật sống đẹp     0.0597
# 16                  Sách quản trị, lãnh đạo     0.0080
# 17                  Sách tài chính, tiền tệ     0.0371
# 18                              Tiểu Thuyết     0.1605
# 19                         Tiểu sử - Hồi ký     0.0053
# 20  Truyện Giả tưởng - Huyền Bí - Phiêu Lưu     0.0332
# 21                               Truyện dài     0.0146
# 22                         Truyện kể cho bé     0.0080
# 23          Truyện ngắn - Tản văn - Tạp Văn     0.1286
# 24                        Truyện tranh Ehon     0.0027
# 25                        Truyện trinh thám     0.0531
# 26                            Truyện đam mỹ     0.0080
# 27                       Tác phẩm kinh điển     0.0345
# 28                     Tô màu - Luyện chữ       0.0000
# 29                        Văn học thiếu nhi     0.0119

# %%
data_new = data_new.merge(frequency_table_cate[['category', 'cate_freq']], on='category')
data_new = data_new.rename(columns={'cate_freq':'cate_freq_new'})

# %%
data_new['cate_freq_new'] = 1 - data_new['cate_freq_new']

# %%
data_new
# Out:
#       product_id  current_price  quantity            category  n_review  \
# 0       74021317          64800     53075         Tiểu Thuyết     11481
# 1      147920903          81000     10000         Tiểu Thuyết      1636
# 2       52788072          65400     17175         Tiểu Thuyết      3033
# 3      114937969          90000      3660         Tiểu Thuyết       777
# 4       70016692          52800      6679         Tiểu Thuyết      1547
# ...          ...            ...       ...                 ...       ...
# 1762    29290844          22000        12  Sách Học Tiếng Hoa         6
# 1763   110181955         149000       531  Sách Học Tiếng Hoa       139
# 1764   169262882         170500        20  Sách Học Tiếng Hoa         1
# 1765     1672721          47000      2802  Sách Học Tiếng Hoa         0
# 1766     1041102          89000       417  Sách Học Tiếng Hoa        15
#
#       avg_rating                          manufacturer  quantity_new  \
# 0            5.0              Nhà Xuất Bản Hội Nhà Văn      0.808784
# 1            4.8              Nhà Xuất Bản Hội Nhà Văn      0.152373
# 2            4.8              Nhà Xuất Bản Hội Nhà Văn      0.261711
# 3            4.8              Nhà Xuất Bản Hội Nhà Văn      0.055759
# 4            4.8              Nhà Xuất Bản Hội Nhà Văn      0.101765
# ...          ...                                   ...           ...
# 1762         5.0                               NXB Trẻ      0.000168
# 1763         4.8               Nhà Xuất Bản Thanh Niên      0.008077
# 1764         5.0                 Nhà Xuất Bản Hồng Đức      0.000290
# 1765         0.0  Nhà Xuất Bản Đại Học Quốc Gia Hà Nội      0.042684
# 1766         4.5  Nhà Xuất Bản Đại Học Quốc Gia Hà Nội      0.006339
#
#       current_price_new  n_review_new  avg_rating_new  manufacturer_new  \
# 0              0.054000      1.000000            1.00            0.5833
# 1              0.067500      0.142496            0.96            0.5833
# 2              0.054500      0.264176            0.96            0.5833
# 3              0.075000      0.067677            0.96            0.5833
# 4              0.044000      0.134744            0.96            0.5833
# ...                 ...           ...             ...               ...
# 1762           0.018333      0.000523            1.00            0.4621
# 1763           0.124167      0.012107            0.96            0.6364
# 1764           0.142083      0.000087            1.00            0.7803
# 1765           0.039167      0.000000            0.00            0.9508
# 1766           0.074167      0.001307            0.90            0.9508
#
#       cate_freq_new
# 0            0.8395
# 1            0.8395
# 2            0.8395
# 3            0.8395
# 4            0.8395
# ...             ...
# 1762         0.9973
# 1763         0.9973
# 1764         0.9973
# 1765         0.9973
# 1766         0.9973
#
# [1767 rows x 13 columns]

# %%
data_new = data_new[["current_price_new","quantity_new","cate_freq_new","n_review_new" ,"avg_rating_new","manufacturer_new",]]
# data_new.to_csv('/content/drive/MyDrive/KPDL/BTL/Datanew.csv')

# %%
data_new
# Out:
#       current_price_new  quantity_new  cate_freq_new  n_review_new  \
# 0              0.054000      0.808784         0.8395      1.000000
# 1              0.067500      0.152373         0.8395      0.142496
# 2              0.054500      0.261711         0.8395      0.264176
# 3              0.075000      0.055759         0.8395      0.067677
# 4              0.044000      0.101765         0.8395      0.134744
# ...                 ...           ...            ...           ...
# 1762           0.018333      0.000168         0.9973      0.000523
# 1763           0.124167      0.008077         0.9973      0.012107
# 1764           0.142083      0.000290         0.9973      0.000087
# 1765           0.039167      0.042684         0.9973      0.000000
# 1766           0.074167      0.006339         0.9973      0.001307
#
#       avg_rating_new  manufacturer_new
# 0               1.00            0.5833
# 1               0.96            0.5833
# 2               0.96            0.5833
# 3               0.96            0.5833
# 4               0.96            0.5833
# ...              ...               ...
# 1762            1.00            0.4621
# 1763            0.96            0.6364
# 1764            1.00            0.7803
# 1765            0.00            0.9508
# 1766            0.90            0.9508
#
# [1767 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import cluster


max_clusters = 10
sse = []
for k in range(1, max_clusters + 1):
  kmeans = KMeans(n_clusters=k, random_state=42)
  kmeans.fit(data_new)
  sse.append(kmeans.inertia_)

plt.plot(range(1, max_clusters + 1), sse, marker = 'o')
plt.xlabel('Số lượng cụm')
plt.ylabel('SSE')
plt.title('Phương pháp Elbow')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data_new['KQ'] = data_new.sum(axis=1)

data_new
# Out:
#       current_price_new  quantity_new  cate_freq_new  n_review_new  \
# 0              0.054000      0.808784         0.8395      1.000000
# 1              0.067500      0.152373         0.8395      0.142496
# 2              0.054500      0.261711         0.8395      0.264176
# 3              0.075000      0.055759         0.8395      0.067677
# 4              0.044000      0.101765         0.8395      0.134744
# ...                 ...           ...            ...           ...
# 1762           0.018333      0.000168         0.9973      0.000523
# 1763           0.124167      0.008077         0.9973      0.012107
# 1764           0.142083      0.000290         0.9973      0.000087
# 1765           0.039167      0.042684         0.9973      0.000000
# 1766           0.074167      0.006339         0.9973      0.001307
#
#       avg_rating_new  manufacturer_new        KQ
# 0               1.00            0.5833  4.285584
# 1               0.96            0.5833  2.745169
# 2               0.96            0.5833  2.963187
# 3               0.96            0.5833  2.581236
# 4               0.96            0.5833  2.663309
# ...              ...               ...       ...
# 1762            1.00            0.4621  2.478424
# 1763            0.96            0.6364  2.738050
# 1764            1.00            0.7803  2.920060
# 1765            0.00            0.9508  2.029951
# 1766            0.90            0.9508  2.929913
#
# [1767 rows x 7 columns]

# %%
import seaborn as sns
# %matplotlib inline
g = sns.relplot(
data = data_new,
x = 'KQ',
y = 'quantity_new',
aspect= 3,
height = 3,
hue = 'avg_rating_new')
g.ax.set_xlabel('Sự chênh lệch khoảng cách bằng phép toán Manhattan')
g.ax.set_ylabel('Tỷ lệ của số lượng sản phẩm bán ra')
g.fig.suptitle('Biểu đồ')
# Out:
# Text(0.5, 0.98, 'Biểu đồ')

# %%
# Gom cụm bằng phương pháp K-Means
from sklearn.cluster import KMeans
from sklearn import cluster
import matplotlib.pyplot as plt

#Phân thành 4 cụm
kmeans = KMeans(n_clusters= 5)

#Tạo tọa độ
data_ToaDo = data_new[['KQ','quantity_new']]

# Nạp tọa độ
kmeans.fit(data_ToaDo)

# Lấy trung tâm của các cụm
centers = kmeans.cluster_centers_
centers.round(4)

25
#Phân vùng bằng thư viện của K-Means
labels = kmeans.labels_
# Vẽ biểu đồ dữ liệu
plt.figure(figsize = (15,5))
plt.scatter(data_new['KQ'], data_new['quantity_new'], c = labels)
plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='x', s = 100)
plt.xlabel('KQ')
plt.ylabel('quantity_new')
plt.show()

# Tạo Class
data_new['PhanLoai'] = labels
data_new['PhanLoai'] = data_new['PhanLoai'].replace({0: 'Top Seller', 1: 'Bán chạy', 2: 'Bán vừa',
3: 'Bán thấp', 4:'Bán tệ'})
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Sử dụng phương pháp KNN dựa trên Class
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report,confusion_matrix

# Phương pháp split test: lấy 20% dữ liệu ban đầu để test
train_df, test_df = train_test_split(data_new, test_size= 0.3, random_state = 42)
knn_model = KNeighborsClassifier( n_neighbors= 9)

knn_model.fit(train_df[["current_price_new","quantity_new","cate_freq_new","n_review_new","avg_rating_new","manufacturer_new","KQ"]],train_df["PhanLoai"])
knn_prediction = knn_model.predict(test_df[["current_price_new","quantity_new","cate_freq_new","n_review_new","avg_rating_new","manufacturer_new","KQ"]])

print("Confusion matrix: ")
print(confusion_matrix(test_df["PhanLoai"],knn_prediction))
print("KNN Classification Report: ")
print(classification_report(test_df["PhanLoai"],knn_prediction))
# Out:
# Confusion matrix:
# [[126   3   0   1   0]
#  [  2  74   0   0   0]
#  [  0   0  81   0   0]
#  [  0   0   0 111   4]
#  [  0   0   1   4 124]]
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#     Bán chạy       0.98      0.97      0.98       130
#     Bán thấp       0.96      0.97      0.97        76
#       Bán tệ       0.99      1.00      0.99        81
#      Bán vừa       0.96      0.97      0.96       115
#   Top Seller       0.97      0.96      0.96       129
#
#     accuracy                           0.97       531
#    macro avg       0.97      0.97      0.97       531
# weighted avg       0.97      0.97      0.97       531

# %%
nb_model = GaussianNB()

nb_model.fit(train_df[["current_price_new","quantity_new","cate_freq_new",
"n_review_new","avg_rating_new","manufacturer_new","KQ"]], train_df["PhanLoai"])

nb_predicious = nb_model.predict(test_df[["current_price_new","quantity_new","cate_freq_new","n_review_new","avg_rating_new","manufacturer_new","KQ"]])

print("Confusion matrix: ")
print(confusion_matrix(test_df["PhanLoai"],nb_predicious))
print("Navie-Bayes Classitification Report: ")
print(classification_report(test_df["PhanLoai"], nb_predicious))
# Out:
# Confusion matrix:
# [[174   8   0   1   0]
#  [  8  87   0   0   0]
#  [  0   0 105   0   1]
#  [  4   0   0 130  15]
#  [  0   0   2  14 158]]
# Navie-Bayes Classitification Report:
#               precision    recall  f1-score   support
#
#     Bán chạy       0.94      0.95      0.94       183
#     Bán thấp       0.92      0.92      0.92        95
#       Bán tệ       0.98      0.99      0.99       106
#      Bán vừa       0.90      0.87      0.88       149
#   Top Seller       0.91      0.91      0.91       174
#
#     accuracy                           0.93       707
#    macro avg       0.93      0.93      0.93       707
# weighted avg       0.92      0.93      0.92       707
